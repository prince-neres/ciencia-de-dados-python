# %%
import pandas
import numpy

def imputation(filename):
    baseball = pandas.read_csv(filename, engine = 'python')
    mediaWeight = round(numpy.mean(baseball['weight']))
    baseball['weight'] = baseball['weight'].fillna(mediaWeight)

    return baseball
  
imputation('Master.csv')
# Out:
#        lahmanID   playerID managerID  ...   retroID    holtzID    bbrefID
# 0             1  aaronha01       NaN  ...  aaroh101  aaronha01  aaronha01
# 1             2  aaronto01       NaN  ...  aarot101  aaronto01  aaronto01
# 2             3   aasedo01       NaN  ...  aased001   aasedo01   aasedo01
# 3             4   abadan01       NaN  ...  abada001   abadan01   abadan01
# 4             5  abadijo01       NaN  ...  abadj101  abadijo01  abadijo01
# ...         ...        ...       ...  ...       ...        ...        ...
# 18120     19416  sulliwi01       NaN  ...       NaN        NaN        NaN
# 18121     19417  gilgahu01       NaN  ...       NaN        NaN        NaN
# 18122     19418  crossjo01       NaN  ...       NaN        NaN        NaN
# 18123     19419  snydech03       NaN  ...       NaN        NaN        NaN
# 18124     19420  ruperja99       NaN  ...       NaN        NaN        NaN
#
# [18125 rows x 33 columns]
